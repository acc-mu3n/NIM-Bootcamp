# %% [markdown]
# <p> <center> <a href="../../Start-NIM-RAG.ipynb">Home Page</a> </center> </p>
#
# <div>
#     <span style="float: left; width: 33%; text-align: left;"><a href="rag_nim_endpoints.ipynb">Previous Notebook</a></span>
#     <span style="float: left; width: 34%; text-align: center;">
#         <a href="rag_nim_endpoints.ipynb">1</a>
#         <a >2</a>
#         <a href="nim_lora_adapter.ipynb">3</a>
#         <!-- <a href="challenge.ipynb">4</a> -->
#     </span>
#     <span style="float: left; width: 33%; text-align: right;"><a href="nim_lora_adapter.ipynb">Next Notebook</a></span>
# </div>

# %% [markdown]
# # ローカライズされたNVIDIA NIMによるRAGの構築
# ---
#
#
# このNotebookでは、ローカライズされたNVIDIA NIM(NVIDIA Inference Microservice)を使用してRAG (検索拡張生成)パイプラインを構築するデモンストレーションを行います。まず初めに、NVIDIA API Keyの設定、NIMイメージの取得とデプロイ、ローカルにデプロイされたNIMを使用するRAGアプリケーションの構築について説明します。

# %% [markdown]
# ### NVIDIA API キーの設定

# %% [markdown]
# 前回のNotebookでは、生成したNVIDIA API KEYの設定方法を学びました。このNotebookの要件として、NVIDIA NIM の docker イメージを取得する為に、環境変数 `NVIDIA_API_KEY` としてキーを設定する必要があります。まだキーを取得していない場合は、NVIDIA NIM API [ホームページ](https://build.nvidia.com/explore/discover) にアクセスしてAPIキーを生成してください。以下のセルを実行し、表示されるテキストボックスにNVIDIA API KEYを入力し、キーボードのEnterキーを押してください。

# %%
import os
import getpass

if not os.environ.get("NVIDIA_API_KEY", "").startswith("nvapi-"):
    nvapi_key = getpass.getpass("Enter your NVIDIA API key: ")
    assert nvapi_key.startswith("nvapi-"), f"{nvapi_key[:5]}... is not a valid key"
    os.environ["NVIDIA_API_KEY"] = nvapi_key
    os.environ["NGC_API_KEY"] = nvapi_key

# %% [markdown]
# ### セルフホスト型NIM

# %% [markdown]
# 以下のセルを実行して、NIM LLMサービスを実行するKubernetesサービスが正常に起動していることを確認してください。

# %%
# !kubectl get pods
# Out:
# No resources found in default namespace.

# %% [markdown]
# **想定される出力**
#
# No resources found in default namespace.

# %% [markdown]
# ### 名前空間 (namespace) の作成
#
# NIMのエンドポイントデプロイの用いる名前空間を作成します

# %%
# !kubectl create namespace nim-llm
# Out:
# Error from server (AlreadyExists): namespaces "nim-llm" already exists

# %% [markdown]
# ### Secretの作成
#
# KubernetesクラスタがNVCR (NVIDIA Container Registry) からイメージをプルし、NIMアプリケーションがNGC APIキーを利用できるように、必要なSecretを作成します。Documentに記載があるように2種類のsecretを作成します。
#
# [Deploying with Helm](https://docs.nvidia.com/nim/large-language-models/latest/deploy-helm.html)

# %%
# !kubectl create secret docker-registry ngc-secret \
  --docker-server=nvcr.io \
  --docker-username='$oauthtoken' \
  --docker-password="${NVIDIA_API_KEY}" \
  --namespace=nim-llm
# Out:
# error: failed to create secret secrets "ngc-secret" already exists

# %%
# !kubectl create secret generic ngc-api \
  --from-literal=NGC_API_KEY="$NVIDIA_API_KEY" \
  -n nim-llm
# Out:
# error: failed to create secret secrets "ngc-api" already exists

# %% [markdown]
# ### NVIDIA NIMの選択

# %% [markdown]
# [NIMs Catalog](https://build.nvidia.com/explore/reasoning)には、さまざまなドメインにおける複数の最先端モデルが掲載されています。下のスクリーンショットのように、`RUN ANYWHERE`タグの付いたものを探してください。これらのNIMイメージはダウンロード可能で、モデルや必要な最適化ランタイムを含んでおり、すぐに使い始めるのに役立ちます。
#
# <img src="imgs/catalog1.jpg" style="width: 900px; height: auto;">
#
# お好みのNIMモデルを選択し、dockerタブをクリックし、以下のスクリーンショットのように赤枠内のイメージ名をコピーします。
#
# <img src="imgs/catalog2.jpg" style="width: 900px; height: auto;">

# %% [markdown]
# ### NIM LLM Helmチャートのダウンロード
#
# ここでは、NIM LLMをKubernetesにデプロイするための設定パッケージ（Helmチャート）をNVIDIAからダウンロードします。この後のセルで実行するコマンドは、認証を行いつつ、指定したバージョンのHelmチャートファイル (.tgz) を手元に取得します。

# %%
# !helm fetch "https://helm.ngc.nvidia.com/nim/charts/nim-llm-1.7.0.tgz" \
    --username='$oauthtoken' \
    --password=$NGC_API_KEY

# %% [markdown]
# ### Endpointデプロイ用のyamlファイルの作成
#
# 次のステップはKubernetesでNIMエンドポイントをデプロイするための設定ファイル (nim_llm.yaml)を作成します。ここでは、`llama3-3.1-swallow-8b-instruct-v0.1`をプルすることでこのステップを実演します。
#
# 以下のセルを実行するとこのノートブックと同じフォルダにnim_llm.yamlが作成されます。

# %%
# %%writefile nim_llm_values.yaml
# image:
#   repository: nvcr.io/nim/tokyotech-llm/llama-3.1-swallow-8b-instruct-v0.1
#   tag: 1.3.2
#
# imagePullSecrets:
#   - name: ngc-secret
#
# model:
#   ngcAPISecret: ngc-api
#   nimCache: /nim-cache
#
# resources:
#   limits:
#     nvidia.com/gpu: 1
#
# persistence:
#   enabled: true
#   size: "50Gi"
#
# startupProbe:
#   initialDelaySeconds: 300
#   periodSeconds: 60
#   failureThreshold: 360
# # TODO startupProbeの値が反映されていない
#
# resources:
#   limits:
#     nvidia.com/gpu: 1
#     memory: "48Gi"
#     # cpu: "7"
#   requests:
#     nvidia.com/gpu: 1
#     memory: "32Gi"
#     # cpu: "4"
# # 初回起動時のOOMエラーがstartupProbeによるものなのか、それとは別にメモリエラーがあるのか切り分けが必要
# Out:
# Overwriting nim_llm_values.yaml

# %% [markdown]
# ### NIM LLM マイクロサービスの起動
#
# 以下のセルを実行し docker run コマンドを実行して NIM LLM マイクロサービスを起動します。

# %%
# !helm install nim-llm-release ./nim-llm-1.7.0.tgz \
  -f /home/turabe/values_swallow.yaml \
  --namespace nim-llm \
  --create-namespace
# Out:
# NAME: nim-llm-release
# LAST DEPLOYED: Tue May 27 19:17:26 2025
# NAMESPACE: nim-llm
# STATUS: deployed
# REVISION: 1
# NOTES:
# Thank you for installing nim-llm.
#
# **************************************************
# | It may take some time for pods to become ready |
# | while model files download                     |
# **************************************************
#
# Your NIM version is: latest

# %%
# !kubectl get pods -n nim-llm
# Out:
# NAME                READY   STATUS    RESTARTS   AGE
# nim-llm-release-0   0/1     Running   0          92s

# %%
# !kubectl describe pods -n nim-llm nim-llm-release-0
# Out:
# Name:             nim-llm-release-0
# Namespace:        nim-llm
# Priority:         0
# Service Account:  default
# Node:             minikube/192.168.49.2
# Start Time:       Tue, 27 May 2025 19:17:33 +0900
# Labels:           app.kubernetes.io/instance=nim-llm-release
#                   app.kubernetes.io/name=nim-llm
#                   apps.kubernetes.io/pod-index=0
#                   controller-revision-hash=nim-llm-release-584fd847cb
#                   statefulset.kubernetes.io/pod-name=nim-llm-release-0
# Annotations:      <none>
# Status:           Running
# IP:               10.244.0.8
# IPs:
#   IP:           10.244.0.8
# Controlled By:  StatefulSet/nim-llm-release
# Containers:
#   nim-llm:
#     Container ID:   docker://8ab7e5f88cb0fa78addb055a4a517265a28cad48f7234241972969a2262c3740
#     Image:          nvcr.io/nim/tokyotech-llm/llama-3.1-swallow-8b-instruct-v0.1:latest
#     Image ID:       docker-pullable://nvcr.io/nim/tokyotech-llm/llama-3.1-swallow-8b-instruct-v0.1@sha256:00dbe414f31d19cb63b09795d40e74bb309456b9cb32f580110a20e4473849d6
#     Port:           8000/TCP
#     Host Port:      0/TCP
#     State:          Running
#       Started:      Tue, 27 May 2025 19:17:33 +0900
#     Ready:          False
#     Restart Count:  0
#     Limits:
#       nvidia.com/gpu:  1
#     Requests:
#       nvidia.com/gpu:  1
#     Liveness:          http-get http://:http-openai/v1/health/live delay=15s timeout=1s period=10s #success=1 #failure=3
#     Readiness:         http-get http://:http-openai/v1/health/ready delay=15s timeout=1s period=10s #success=1 #failure=3
#     Startup:           http-get http://:http-openai/v1/health/ready delay=40s timeout=1s period=10s #success=1 #failure=180
#     Environment:
#       NIM_CACHE_PATH:      /model-store
#       NGC_API_KEY:         <set to the key 'NGC_API_KEY' in secret 'ngc-api'>  Optional: false
#       OUTLINES_CACHE_DIR:  /tmp/outlines
#       NIM_SERVER_PORT:     8000
#       NIM_JSONL_LOGGING:   1
#       NIM_LOG_LEVEL:       INFO
#     Mounts:
#       /dev/shm from dshm (rw)
#       /model-store from model-store (rw)
#       /scripts from scripts-volume (rw)
#       /var/run/secrets/kubernetes.io/serviceaccount from kube-api-access-fpdxf (ro)
# Conditions:
#   Type                        Status
#   PodReadyToStartContainers   True
#   Initialized                 True
#   Ready                       False
#   ContainersReady             False
#   PodScheduled                True
# Volumes:
#   model-store:
#     Type:       PersistentVolumeClaim (a reference to a PersistentVolumeClaim in the same namespace)
#     ClaimName:  model-store-nim-llm-release-0
#     ReadOnly:   false
#   dshm:
#     Type:       EmptyDir (a temporary directory that shares a pod's lifetime)
#     Medium:     Memory
#     SizeLimit:  <unset>
#   scripts-volume:
#     Type:      ConfigMap (a volume populated by a ConfigMap)
#     Name:      nim-llm-release-scripts-configmap
#     Optional:  false
#   kube-api-access-fpdxf:
#     Type:                    Projected (a volume that contains injected data from multiple sources)
#     TokenExpirationSeconds:  3607
#     ConfigMapName:           kube-root-ca.crt
#     ConfigMapOptional:       <nil>
#     DownwardAPI:             true
# QoS Class:                   BestEffort
# Node-Selectors:              <none>
# Tolerations:                 node.kubernetes.io/not-ready:NoExecute op=Exists for 300s
#                              node.kubernetes.io/unreachable:NoExecute op=Exists for 300s
#                              nvidia.com/gpu:NoSchedule op=Exists
# Events:
#   Type     Reason     Age               From               Message
#   ----     ------     ----              ----               -------
#   Normal   Scheduled  91s               default-scheduler  Successfully assigned nim-llm/nim-llm-release-0 to minikube
#   Normal   Pulled     85s               kubelet            Container image "nvcr.io/nim/tokyotech-llm/llama-3.1-swallow-8b-instruct-v0.1:latest" already present on machine
#   Normal   Created    85s               kubelet            Created container nim-llm
#   Normal   Started    84s               kubelet            Started container nim-llm
#   Warning  Unhealthy  5s (x5 over 45s)  kubelet            Startup probe failed: Get "http://10.244.0.8:8000/v1/health/ready": dial tcp 10.244.0.8:8000: connect: connection refused

# %%
# !kubectl logs nim-llm-release-0 -n nim-llm
# Out:
# ===========================================
# == NVIDIA Inference Microservice LLM NIM ==
# ===========================================
#
# NVIDIA Inference Microservice LLM NIM Version 1.3.0
# Model: tokyotech-llm/llama-3.1-swallow-8b-instruct-v0.1
#
# Container image Copyright (c) 2016-2024, NVIDIA CORPORATION & AFFILIATES. All rights reserved.
#
# The NIM container is governed by the NVIDIA Software License Agreement (https://www.nvidia.com/en-us/agreements/enterprise-software/nvidia-software-license-agreement/) and Product-Specific Terms for AI Products (https://www.nvidia.com/en-us/agreements/enterprise-software/product-specific-terms-for-ai-products/)
#
#
# A copy of this license can be found under /opt/nim/LICENSE.
#
#
# The use of this model is governed by the NVIDIA AI Foundation Models Community License (https://www.nvidia.com/en-us/agreements/enterprise-software/nvidia-ai-foundation-models-community-license-agreement/).
#
#
# ADDITIONAL INFORMATION: (a) Llama 3.1 Community License Agreement (https://www.llama.com/llama3_1/license/). Built with Llama; and (b) Gemma Terms of Use | Google AI for Developers (https://ai.google.dev/gemma/terms) and Gemma Prohibited Use Policy | Google AI for Developers (https://ai.google.dev/gemma/prohibited_use_policy).
#
#
#
# {"level": "None", "time": "None", "file_name": "None", "file_path": "None", "line_number": "-1", "message": "You are using a deprecated `pynvml` package. Please install `nvidia-ml-py` instead. See https://pypi.org/project/pynvml for more information.", "exc_info": "None", "stack_info": "None"}
# {"level": "None", "time": "None", "file_name": "None", "file_path": "None", "line_number": "-1", "message": "Profile 375dc0ff86133c2a423fbe9ef46d8fdf12d6403b3caa3b8e70d7851a89fc90dd is not fully defined with checksums", "exc_info": "None", "stack_info": "None"}
# {"level": "None", "time": "None", "file_name": "None", "file_path": "None", "line_number": "-1", "message": "Profile 4f904d571fe60ff24695b5ee2aa42da58cb460787a968f1e8a09f5a7e862728d is not fully defined with checksums", "exc_info": "None", "stack_info": "None"}
# {"level": "None", "time": "None", "file_name": "None", "file_path": "None", "line_number": "-1", "message": "Profile 54946b08b79ecf9e7f2d5c000234bf2cce19c8fee21b243c1a084b03897e8c95 is not fully defined with checksums", "exc_info": "None", "stack_info": "None"}
# {"level": "None", "time": "None", "file_name": "None", "file_path": "None", "line_number": "-1", "message": "Profile 7fa4a5a68c0338f16aef61de94977acfdacb7cabd848d38c49c48d2f639f04b3 is not fully defined with checksums", "exc_info": "None", "stack_info": "None"}
# {"level": "None", "time": "None", "file_name": "None", "file_path": "None", "line_number": "-1", "message": "Profile ac34857f8dcbd174ad524974248f2faf271bd2a0355643b2cf1490d0fe7787c2 is not fully defined with checksums", "exc_info": "None", "stack_info": "None"}
# {"level": "None", "time": "None", "file_name": "None", "file_path": "None", "line_number": "-1", "message": "Profile c84b2a068e56a551906563035ed77f88c88cbe1a63c6768fb2d4a9e0af1e67ba is not fully defined with checksums", "exc_info": "None", "stack_info": "None"}
# {"level": "INFO", "time": "2025-05-27 10:17:39.554", "file_name": "ngc_profile.py", "file_path": "/opt/nim/llm/nim_llm_sdk/hub/ngc_profile.py", "line_number": "267", "message": "Running NIM without LoRA. Only looking for compatible profiles that do not support LoRA.", "exc_info": "None", "stack_info": "None"}
# {"level": "INFO", "time": "2025-05-27 10:17:39.555", "file_name": "ngc_profile.py", "file_path": "/opt/nim/llm/nim_llm_sdk/hub/ngc_profile.py", "line_number": "269", "message": "Detected 2 compatible profile(s).", "exc_info": "None", "stack_info": "None"}
# {"level": "INFO", "time": "2025-05-27 10:17:39.555", "file_name": "ngc_injector.py", "file_path": "/opt/nim/llm/nim_llm_sdk/hub/ngc_injector.py", "line_number": "151", "message": "Valid profile: ac34857f8dcbd174ad524974248f2faf271bd2a0355643b2cf1490d0fe7787c2 (tensorrt_llm-trtllm_buildable-bf16-tp1-pp1) on GPUs [0]", "exc_info": "None", "stack_info": "None"}
# {"level": "INFO", "time": "2025-05-27 10:17:39.555", "file_name": "ngc_injector.py", "file_path": "/opt/nim/llm/nim_llm_sdk/hub/ngc_injector.py", "line_number": "151", "message": "Valid profile: 4f904d571fe60ff24695b5ee2aa42da58cb460787a968f1e8a09f5a7e862728d (vllm-bf16-tp1-pp1) on GPUs [0]", "exc_info": "None", "stack_info": "None"}
# {"level": "INFO", "time": "2025-05-27 10:17:39.555", "file_name": "ngc_injector.py", "file_path": "/opt/nim/llm/nim_llm_sdk/hub/ngc_injector.py", "line_number": "271", "message": "Selected profile: ac34857f8dcbd174ad524974248f2faf271bd2a0355643b2cf1490d0fe7787c2 (tensorrt_llm-trtllm_buildable-bf16-tp1-pp1)", "exc_info": "None", "stack_info": "None"}
# {"level": "INFO", "time": "2025-05-27 10:17:39.555", "file_name": "ngc_injector.py", "file_path": "/opt/nim/llm/nim_llm_sdk/hub/ngc_injector.py", "line_number": "279", "message": "Profile metadata: feat_lora: false", "exc_info": "None", "stack_info": "None"}
# {"level": "INFO", "time": "2025-05-27 10:17:39.555", "file_name": "ngc_injector.py", "file_path": "/opt/nim/llm/nim_llm_sdk/hub/ngc_injector.py", "line_number": "279", "message": "Profile metadata: llm_engine: tensorrt_llm", "exc_info": "None", "stack_info": "None"}
# {"level": "INFO", "time": "2025-05-27 10:17:39.555", "file_name": "ngc_injector.py", "file_path": "/opt/nim/llm/nim_llm_sdk/hub/ngc_injector.py", "line_number": "279", "message": "Profile metadata: pp: 1", "exc_info": "None", "stack_info": "None"}
# {"level": "INFO", "time": "2025-05-27 10:17:39.555", "file_name": "ngc_injector.py", "file_path": "/opt/nim/llm/nim_llm_sdk/hub/ngc_injector.py", "line_number": "279", "message": "Profile metadata: precision: bf16", "exc_info": "None", "stack_info": "None"}
# {"level": "INFO", "time": "2025-05-27 10:17:39.555", "file_name": "ngc_injector.py", "file_path": "/opt/nim/llm/nim_llm_sdk/hub/ngc_injector.py", "line_number": "279", "message": "Profile metadata: tp: 1", "exc_info": "None", "stack_info": "None"}
# {"level": "INFO", "time": "2025-05-27 10:17:39.555", "file_name": "ngc_injector.py", "file_path": "/opt/nim/llm/nim_llm_sdk/hub/ngc_injector.py", "line_number": "279", "message": "Profile metadata: trtllm_buildable: true", "exc_info": "None", "stack_info": "None"}
# {"level": "INFO", "time": "2025-05-27 10:17:39.558", "file_name": "launch.py", "file_path": "/opt/nim/llm/nim_llm_sdk/entrypoints/launch.py", "line_number": "46", "message": "engine_world_size=1", "exc_info": "None", "stack_info": "None"}
# {"level": "INFO", "time": "2025-05-27 10:17:39.558", "file_name": "launch.py", "file_path": "/opt/nim/llm/nim_llm_sdk/entrypoints/launch.py", "line_number": "92", "message": "running command ['/opt/nim/llm/.venv/bin/python3', '-m', 'nim_llm_sdk.entrypoints.openai.api_server', '--served-model-name', 'tokyotech-llm/llama-3.1-swallow-8b-instruct-v0.1', '--async-engine-args', '{\"model\": \"/tmp/LLM-13u96al7\", \"served_model_name\": [\"tokyotech-llm/llama-3.1-swallow-8b-instruct-v0.1\"], \"tokenizer\": \"/tmp/LLM-13u96al7\", \"skip_tokenizer_init\": false, \"tokenizer_mode\": \"auto\", \"trust_remote_code\": false, \"download_dir\": null, \"load_format\": \"auto\", \"dtype\": \"bfloat16\", \"kv_cache_dtype\": \"auto\", \"quantization_param_path\": null, \"seed\": 0, \"max_model_len\": null, \"worker_use_ray\": false, \"distributed_executor_backend\": \"mp\", \"pipeline_parallel_size\": 1, \"tensor_parallel_size\": 1, \"max_parallel_loading_workers\": null, \"block_size\": 16, \"enable_prefix_caching\": false, \"disable_sliding_window\": false, \"use_v2_block_manager\": false, \"swap_space\": 4, \"cpu_offload_gb\": 0, \"gpu_memory_utilization\": 0.9, \"max_num_batched_tokens\": null, \"max_num_seqs\": 256, \"max_logprobs\": 20, \"disable_log_stats\": false, \"revision\": null, \"code_revision\": null, \"rope_scaling\": null, \"rope_theta\": null, \"tokenizer_revision\": null, \"quantization\": null, \"enforce_eager\": false, \"max_context_len_to_capture\": null, \"max_seq_len_to_capture\": 8192, \"disable_custom_all_reduce\": false, \"tokenizer_pool_size\": 0, \"tokenizer_pool_type\": \"ray\", \"tokenizer_pool_extra_config\": null, \"limit_mm_per_prompt\": null, \"enable_lora\": false, \"enable_dora\": false, \"max_loras\": 8, \"max_lora_rank\": 32, \"enable_prompt_adapter\": false, \"max_prompt_adapters\": 1, \"max_prompt_adapter_token\": 0, \"fully_sharded_loras\": false, \"lora_extra_vocab_size\": 256, \"long_lora_scaling_factors\": null, \"lora_dtype\": \"auto\", \"max_cpu_loras\": 16, \"peft_source\": null, \"peft_refresh_interval\": null, \"device\": \"auto\", \"num_scheduler_steps\": 1, \"ray_workers_use_nsight\": false, \"num_gpu_blocks_override\": null, \"num_lookahead_slots\": 0, \"model_loader_extra_config\": null, \"ignore_patterns\": [], \"preemption_mode\": null, \"scheduler_delay_factor\": 0.0, \"enable_chunked_prefill\": null, \"guided_decoding_backend\": \"outlines\", \"speculative_model\": null, \"speculative_model_quantization\": null, \"speculative_draft_tensor_parallel_size\": null, \"num_speculative_tokens\": null, \"speculative_max_model_len\": null, \"speculative_disable_by_batch_size\": null, \"ngram_prompt_lookup_max\": null, \"ngram_prompt_lookup_min\": null, \"spec_decoding_acceptance_method\": \"rejection_sampler\", \"typical_acceptance_sampler_posterior_threshold\": null, \"typical_acceptance_sampler_posterior_alpha\": null, \"qlora_adapter_name_or_path\": null, \"disable_logprobs_during_spec_decoding\": null, \"otlp_traces_endpoint\": null, \"collect_detailed_traces\": null, \"engine_use_ray\": false, \"disable_log_requests\": true, \"selected_gpus\": [{\"name\": \"NVIDIA RTX 5880 Ada Generation\", \"device_index\": 0, \"device_id\": \"26b3:10de\", \"total_memory\": 51527024640, \"free_memory\": 50858426368, \"used_memory\": 18415616, \"reserved_memory\": 650182656, \"compute_capability\": [8, 9], \"family\": \"RTX A6000 Ada\"}], \"tllm_buildable\": true, \"tllm_config_json_str\": null, \"profile_id\": \"ac34857f8dcbd174ad524974248f2faf271bd2a0355643b2cf1490d0fe7787c2\", \"quantization_algo\": null}']", "exc_info": "None", "stack_info": "None"}
# {"level": "None", "time": "None", "file_name": "None", "file_path": "None", "line_number": "-1", "message": "[1748341061.300474] [nim-llm-release-0:54   :0]          parser.c:2305 UCX  WARN  unused environment variables: UCX_HOME; UCX_DIR (maybe: UCX_TLS?)", "exc_info": "None", "stack_info": "None"}
# {"level": "None", "time": "None", "file_name": "None", "file_path": "None", "line_number": "-1", "message": "[1748341061.300474] [nim-llm-release-0:54   :0]          parser.c:2305 UCX  WARN  (set UCX_WARN_UNUSED_ENV_VARS=n to suppress this warning)", "exc_info": "None", "stack_info": "None"}
# {"level": "None", "time": "None", "file_name": "None", "file_path": "None", "line_number": "-1", "message": "You are using a deprecated `pynvml` package. Please install `nvidia-ml-py` instead. See https://pypi.org/project/pynvml for more information.", "exc_info": "None", "stack_info": "None"}
# {"level": "WARNING", "time": "2025-05-27 10:17:45.587", "file_name": "None", "file_path": "None", "line_number": "-1", "message": "[TRT-LLM] [W] Logger level already set from environment. Discard new verbosity: error", "exc_info": "None", "stack_info": "None"}
# {"level": "INFO", "time": "2025-05-27 10:17:45.587", "file_name": "None", "file_path": "None", "line_number": "-1", "message": "[TRT-LLM] [I] Starting TensorRT-LLM init.", "exc_info": "None", "stack_info": "None"}
# {"level": "INFO", "time": "None", "file_name": "None", "file_path": "None", "line_number": "-1", "message": "[TensorRT-LLM][INFO] Set logger level to INFO", "exc_info": "None", "stack_info": "None"}
# {"level": "INFO", "time": "2025-05-27 10:17:45.592", "file_name": "None", "file_path": "None", "line_number": "-1", "message": "[TRT-LLM] [I] TensorRT-LLM inited.", "exc_info": "None", "stack_info": "None"}
# {"level": "None", "time": "None", "file_name": "None", "file_path": "None", "line_number": "-1", "message": "[TensorRT-LLM] TensorRT-LLM version: 0.12.3", "exc_info": "None", "stack_info": "None"}
# {"level": "INFO", "time": "2025-05-27 10:17:45.760", "file_name": "api_server.py", "file_path": "/opt/nim/llm/nim_llm_sdk/entrypoints/openai/api_server.py", "line_number": "722", "message": "NIM LLM API version 1.3.0", "exc_info": "None", "stack_info": "None"}
# {"level": "INFO", "time": "2025-05-27 10:17:45.761", "file_name": "utils.py", "file_path": "/opt/nim/llm/nim_llm_sdk/trtllm/utils.py", "line_number": "237", "message": "Using provided selected GPUs list [0]", "exc_info": "None", "stack_info": "None"}
# {"level": "INFO", "time": "2025-05-27 10:17:45.780", "file_name": "dynamic_module_loader.py", "file_path": "/opt/nim/llm/nim_llm_sdk/model_specific_modules/dynamic_module_loader.py", "line_number": "92", "message": "Loading dynamic modules from /opt/nim/llm/nim_llm_sdk/model_specific_modules", "exc_info": "None", "stack_info": "None"}
# {"level": "WARNING", "time": "2025-05-27 10:17:45.783", "file_name": "modeling_rope_utils.py", "file_path": "/opt/nim/llm/.venv/lib/python3.10/site-packages/transformers/modeling_rope_utils.py", "line_number": "526", "message": "`rope_scaling`'s original_max_position_embeddings field must be less than max_position_embeddings, got 8192 and max_position_embeddings=8192", "exc_info": "None", "stack_info": "None"}
# {"level": "INFO", "time": "2025-05-27 10:17:45.783", "file_name": "async_trtllm_engine.py", "file_path": "/opt/nim/llm/nim_llm_sdk/engine/async_trtllm_engine.py", "line_number": "81", "message": "Initializing an LLM engine (v1.3.0) with config: model='/tmp/LLM-13u96al7', speculative_config=None, tokenizer='/tmp/LLM-13u96al7', tokenizer_mode=auto, revision=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.bfloat16, max_seq_len=8192, download_dir=None, load_format=auto, tensor_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, kv_cache_dtype=auto, quantization_param_path=None, device_config=cuda, decoding_config=DecodingConfig(guided_decoding_backend='outlines'), seed=0)", "exc_info": "None", "stack_info": "None"}
# {"level": "INFO", "time": "2025-05-27 10:17:45.926", "file_name": "utils.py", "file_path": "/opt/nim/llm/nim_llm_sdk/trtllm/utils.py", "line_number": "285", "message": "Building rank 0 with config ConstrainedTrtllmConfig(dtype='bfloat16', pp_size=1, tp_size=1, max_batch_size=512, max_seq_len=8192, max_num_tokens=8192, lora=ConstrainedTrtllmLoraConfig(enable=False, modules=['attn_qkv', 'attn_q', 'attn_k', 'attn_v', 'attn_dense', 'mlp_h_to_4h', 'mlp_4h_to_h', 'mlp_gate'], max_rank=64), quant_config=None, gpus_per_node=1)", "exc_info": "None", "stack_info": "None"}
# {"level": "INFO", "time": "2025-05-27 10:17:45.926", "file_name": "build_utils.py", "file_path": "/opt/nim/llm/nim_llm_sdk/trtllm/weight_manager/build_utils.py", "line_number": "144", "message": "Detected model architecture: LlamaForCausalLM", "exc_info": "None", "stack_info": "None"}
# {"level": "WARNING", "time": "2025-05-27 10:17:45.927", "file_name": "modeling_rope_utils.py", "file_path": "/opt/nim/llm/.venv/lib/python3.10/site-packages/transformers/modeling_rope_utils.py", "line_number": "526", "message": "`rope_scaling`'s original_max_position_embeddings field must be less than max_position_embeddings, got 8192 and max_position_embeddings=8192", "exc_info": "None", "stack_info": "None"}
# {"level": "None", "time": "None", "file_name": "None", "file_path": "None", "line_number": "-1", "message": "\r0it [00:00, ?it/s]\r4it [00:00, 39.60it/s]\r139it [00:00, 797.44it/s]\r230it [00:00, 964.38it/s]", "exc_info": "None", "stack_info": "None"}
# {"level": "INFO", "time": "2025-05-27 10:17:46.178", "file_name": "build_utils.py", "file_path": "/opt/nim/llm/nim_llm_sdk/trtllm/weight_manager/build_utils.py", "line_number": "192", "message": "Total time of reading and converting rank0 checkpoint: 0.25 s", "exc_info": "None", "stack_info": "None"}
# {"level": "INFO", "time": "2025-05-27 10:17:46.178", "file_name": "logger.py", "file_path": "/opt/nim/llm/.venv/lib/python3.10/site-packages/tensorrt_llm/logger.py", "line_number": "93", "message": "[TRT-LLM] [I] Set dtype to bfloat16.", "exc_info": "None", "stack_info": "None"}
# {"level": "WARNING", "time": "2025-05-27 10:17:46.178", "file_name": "logger.py", "file_path": "/opt/nim/llm/.venv/lib/python3.10/site-packages/tensorrt_llm/logger.py", "line_number": "93", "message": "[TRT-LLM] [W] remove_input_padding is enabled, while opt_num_tokens is not set, setting to max_batch_size*max_beam_width. \n", "exc_info": "None", "stack_info": "None"}
# {"level": "WARNING", "time": "2025-05-27 10:17:46.178", "file_name": "logger.py", "file_path": "/opt/nim/llm/.venv/lib/python3.10/site-packages/tensorrt_llm/logger.py", "line_number": "93", "message": "[TRT-LLM] [W] padding removal and fMHA are both enabled, max_input_len is not required and will be ignored", "exc_info": "None", "stack_info": "None"}
# {"level": "None", "time": "None", "file_name": "None", "file_path": "None", "line_number": "-1", "message": "[05/27/2025-10:17:46] [TRT] [I] [MemUsageChange] Init CUDA: CPU +14, GPU +0, now: CPU 2775, GPU 356 (MiB)", "exc_info": "None", "stack_info": "None"}
# {"level": "None", "time": "None", "file_name": "None", "file_path": "None", "line_number": "-1", "message": "[05/27/2025-10:17:47] [TRT] [I] [MemUsageChange] Init builder kernel library: CPU +2191, GPU +418, now: CPU 5121, GPU 774 (MiB)", "exc_info": "None", "stack_info": "None"}
# {"level": "None", "time": "None", "file_name": "None", "file_path": "None", "line_number": "-1", "message": "[05/27/2025-10:17:47] [TRT] [W] profileSharing0806 is on by default in TensorRT 10.0. This flag is deprecated and has no effect.", "exc_info": "None", "stack_info": "None"}
# {"level": "INFO", "time": "2025-05-27 10:17:47.769", "file_name": "logger.py", "file_path": "/opt/nim/llm/.venv/lib/python3.10/site-packages/tensorrt_llm/logger.py", "line_number": "93", "message": "[TRT-LLM] [I] Set nccl_plugin to None.", "exc_info": "None", "stack_info": "None"}
# {"level": "INFO", "time": "2025-05-27 10:17:47.902", "file_name": "logger.py", "file_path": "/opt/nim/llm/.venv/lib/python3.10/site-packages/tensorrt_llm/logger.py", "line_number": "93", "message": "[TRT-LLM] [I] Total optimization profiles added: 1", "exc_info": "None", "stack_info": "None"}
# {"level": "INFO", "time": "2025-05-27 10:17:47.903", "file_name": "logger.py", "file_path": "/opt/nim/llm/.venv/lib/python3.10/site-packages/tensorrt_llm/logger.py", "line_number": "93", "message": "[TRT-LLM] [I] Build TensorRT engine Unnamed Network 0", "exc_info": "None", "stack_info": "None"}
# {"level": "None", "time": "None", "file_name": "None", "file_path": "None", "line_number": "-1", "message": "[05/27/2025-10:17:47] [TRT] [W] Unused Input: position_ids", "exc_info": "None", "stack_info": "None"}
# {"level": "None", "time": "None", "file_name": "None", "file_path": "None", "line_number": "-1", "message": "[05/27/2025-10:17:47] [TRT] [W] [RemoveDeadLayers] Input Tensor position_ids is unused or used only at compile-time, but is not being removed.", "exc_info": "None", "stack_info": "None"}
# {"level": "None", "time": "None", "file_name": "None", "file_path": "None", "line_number": "-1", "message": "[05/27/2025-10:17:47] [TRT] [I] Global timing cache in use. Profiling results in this builder pass will be stored.", "exc_info": "None", "stack_info": "None"}
# {"level": "None", "time": "None", "file_name": "None", "file_path": "None", "line_number": "-1", "message": "[05/27/2025-10:18:35] [TRT] [I] [GraphReduction] The approximate region cut reduction algorithm is called.", "exc_info": "None", "stack_info": "None"}
# {"level": "None", "time": "None", "file_name": "None", "file_path": "None", "line_number": "-1", "message": "[05/27/2025-10:18:35] [TRT] [I] Detected 15 inputs and 1 output network tensors.", "exc_info": "None", "stack_info": "None"}
# {"level": "None", "time": "None", "file_name": "None", "file_path": "None", "line_number": "-1", "message": "[05/27/2025-10:18:36] [TRT] [I] Total Host Persistent Memory: 50240", "exc_info": "None", "stack_info": "None"}
# {"level": "None", "time": "None", "file_name": "None", "file_path": "None", "line_number": "-1", "message": "[05/27/2025-10:18:36] [TRT] [I] Total Device Persistent Memory: 0", "exc_info": "None", "stack_info": "None"}
# {"level": "None", "time": "None", "file_name": "None", "file_path": "None", "line_number": "-1", "message": "[05/27/2025-10:18:36] [TRT] [I] Total Scratch Memory: 671088640", "exc_info": "None", "stack_info": "None"}
# {"level": "None", "time": "None", "file_name": "None", "file_path": "None", "line_number": "-1", "message": "[05/27/2025-10:18:36] [TRT] [I] [BlockAssignment] Started assigning block shifts. This will take 174 steps to complete.", "exc_info": "None", "stack_info": "None"}
# {"level": "None", "time": "None", "file_name": "None", "file_path": "None", "line_number": "-1", "message": "[05/27/2025-10:18:36] [TRT] [I] [BlockAssignment] Algorithm ShiftNTopDown took 3.40822ms to assign 19 blocks to 174 nodes requiring 1003757056 bytes.", "exc_info": "None", "stack_info": "None"}
# {"level": "None", "time": "None", "file_name": "None", "file_path": "None", "line_number": "-1", "message": "[05/27/2025-10:18:36] [TRT] [I] Total Activation Memory: 1003755008", "exc_info": "None", "stack_info": "None"}
# {"level": "None", "time": "None", "file_name": "None", "file_path": "None", "line_number": "-1", "message": "[05/27/2025-10:18:37] [TRT] [I] Total Weights Memory: 16064717568", "exc_info": "None", "stack_info": "None"}
# {"level": "None", "time": "None", "file_name": "None", "file_path": "None", "line_number": "-1", "message": "[05/27/2025-10:18:37] [TRT] [I] Engine generation completed in 49.4946 seconds.", "exc_info": "None", "stack_info": "None"}
# {"level": "None", "time": "None", "file_name": "None", "file_path": "None", "line_number": "-1", "message": "[05/27/2025-10:18:37] [TRT] [I] [MemUsageStats] Peak memory usage of TRT CPU/GPU memory allocators: CPU 2100 MiB, GPU 15321 MiB", "exc_info": "None", "stack_info": "None"}
# {"level": "None", "time": "None", "file_name": "None", "file_path": "None", "line_number": "-1", "message": "[05/27/2025-10:18:44] [TRT] [I] [MemUsageStats] Peak memory usage during Engine building and serialization: CPU: 40181 MiB", "exc_info": "None", "stack_info": "None"}
# {"level": "INFO", "time": "2025-05-27 10:18:44.630", "file_name": "logger.py", "file_path": "/opt/nim/llm/.venv/lib/python3.10/site-packages/tensorrt_llm/logger.py", "line_number": "93", "message": "[TRT-LLM] [I] Total time of building Unnamed Network 0: 00:00:56", "exc_info": "None", "stack_info": "None"}
# {"level": "INFO", "time": "2025-05-27 10:18:44.630", "file_name": "logger.py", "file_path": "/opt/nim/llm/.venv/lib/python3.10/site-packages/tensorrt_llm/logger.py", "line_number": "93", "message": "[TRT-LLM] [I] Build phase peak memory: 40184.14 MB, children: 16.00 MB", "exc_info": "None", "stack_info": "None"}
# {"level": "INFO", "time": "2025-05-27 10:18:44.631", "file_name": "build_utils.py", "file_path": "/opt/nim/llm/nim_llm_sdk/trtllm/weight_manager/build_utils.py", "line_number": "204", "message": "Total time of building rank0 engine: 58.45 s", "exc_info": "None", "stack_info": "None"}
# {"level": "WARNING", "time": "2025-05-27 10:18:44.759", "file_name": "logger.py", "file_path": "/opt/nim/llm/.venv/lib/python3.10/site-packages/tensorrt_llm/logger.py", "line_number": "93", "message": "[TRT-LLM] [W] Implicitly setting PretrainedConfig.mlp_bias = False", "exc_info": "None", "stack_info": "None"}
# {"level": "WARNING", "time": "2025-05-27 10:18:44.759", "file_name": "logger.py", "file_path": "/opt/nim/llm/.venv/lib/python3.10/site-packages/tensorrt_llm/logger.py", "line_number": "93", "message": "[TRT-LLM] [W] Implicitly setting PretrainedConfig.attn_bias = False", "exc_info": "None", "stack_info": "None"}
# {"level": "WARNING", "time": "2025-05-27 10:18:44.759", "file_name": "logger.py", "file_path": "/opt/nim/llm/.venv/lib/python3.10/site-packages/tensorrt_llm/logger.py", "line_number": "93", "message": "[TRT-LLM] [W] Implicitly setting PretrainedConfig.rotary_base = 500000.0", "exc_info": "None", "stack_info": "None"}
# {"level": "WARNING", "time": "2025-05-27 10:18:44.759", "file_name": "logger.py", "file_path": "/opt/nim/llm/.venv/lib/python3.10/site-packages/tensorrt_llm/logger.py", "line_number": "93", "message": "[TRT-LLM] [W] Implicitly setting PretrainedConfig.rotary_scaling = {'factor': 8.0, 'high_freq_factor': 4.0, 'low_freq_factor': 1.0, 'original_max_position_embeddings': 8192, 'rope_type': 'llama3'}", "exc_info": "None", "stack_info": "None"}
# {"level": "WARNING", "time": "2025-05-27 10:18:44.759", "file_name": "logger.py", "file_path": "/opt/nim/llm/.venv/lib/python3.10/site-packages/tensorrt_llm/logger.py", "line_number": "93", "message": "[TRT-LLM] [W] Implicitly setting PretrainedConfig.residual_mlp = False", "exc_info": "None", "stack_info": "None"}
# {"level": "WARNING", "time": "2025-05-27 10:18:44.759", "file_name": "logger.py", "file_path": "/opt/nim/llm/.venv/lib/python3.10/site-packages/tensorrt_llm/logger.py", "line_number": "93", "message": "[TRT-LLM] [W] Implicitly setting PretrainedConfig.disable_weight_only_quant_plugin = False", "exc_info": "None", "stack_info": "None"}
# {"level": "WARNING", "time": "2025-05-27 10:18:44.759", "file_name": "logger.py", "file_path": "/opt/nim/llm/.venv/lib/python3.10/site-packages/tensorrt_llm/logger.py", "line_number": "93", "message": "[TRT-LLM] [W] Implicitly setting PretrainedConfig.moe = {'num_experts': 0, 'top_k': 0, 'normalization_mode': None, 'tp_mode': 0}", "exc_info": "None", "stack_info": "None"}
# {"level": "WARNING", "time": "2025-05-27 10:18:44.759", "file_name": "logger.py", "file_path": "/opt/nim/llm/.venv/lib/python3.10/site-packages/tensorrt_llm/logger.py", "line_number": "93", "message": "[TRT-LLM] [W] Implicitly setting PretrainedConfig.remove_duplicated_kv_heads = False", "exc_info": "None", "stack_info": "None"}

# %% [markdown]
# **想定される出力**
#
# ```
# ===========================================
# == NVIDIA Inference Microservice LLM NIM ==
# ===========================================
#
# NVIDIA Inference Microservice LLM NIM Version 1.3.0
# Model: tokyotech-llm/llama-3.1-swallow-8b-instruct-v0.1
#
# Container image Copyright (c) 2016-2024, NVIDIA CORPORATION & AFFILIATES. All rights reserved.
#
# The NIM container is governed by the NVIDIA Software License Agreement (https://www.nvidia.com/en-us/agreements/enterprise-software/nvidia-software-license-agreement/) and Product-Specific Terms for AI Products (https://www.nvidia.com/en-us/agreements/enterprise-software/product-specific-terms-for-ai-products/)
#
#
# A copy of this license can be found under /opt/nim/LICENSE.
#
#
# The use of this model is governed by the NVIDIA AI Foundation Models Community License (https://www.nvidia.com/en-us/agreements/enterprise-software/nvidia-ai-foundation-models-community-license-agreement/).
#
#
# ADDITIONAL INFORMATION: (a) Llama 3.1 Community License Agreement (https://www.llama.com/llama3_1/license/). Built with Llama; and (b) Gemma Terms of Use | Google AI for Developers (https://ai.google.dev/gemma/terms) and Gemma Prohibited Use Policy | Google AI for Developers (https://ai.google.dev/gemma/prohibited_use_policy).
#
#
#
# {"level": "None", "time": "None", "file_name": "None", "file_path": "None", "line_number": "-1", "message": "You are using a deprecated `pynvml` package. Please install `nvidia-ml-py` instead. See https://pypi.org/project/pynvml for more information.", "exc_info": "None", "stack_info": "None"}
# {"level": "None", "time": "None", "file_name": "None", "file_path": "None", "line_number": "-1", "message": "Profile 375dc0ff86133c2a423fbe9ef46d8fdf12d6403b3caa3b8e70d7851a89fc90dd is not fully defined with checksums", "exc_info": "None", "stack_info": "None"}
# ...
# {"level": "INFO", "time": "2025-05-27 09:57:39.923", "file_name": "httptools_impl.py", "file_path": "/opt/nim/llm/.venv/lib/python3.10/site-packages/uvicorn/protocols/http/httptools_impl.py", "line_number": "481", "message": "127.0.0.1:47306 - \"POST /v1/chat/completions HTTP/1.1\" 200", "exc_info": "None", "stack_info": "None"}
# {"level": "INFO", "time": "None", "file_name": "None", "file_path": "None", "line_number": "-1", "message": "[TensorRT-LLM][INFO] Ignoring already terminated request 3", "exc_info": "None", "stack_info": "None"}
# {"level": "INFO", "time": "2025-05-27 09:57:47.415", "file_name": "httptools_impl.py", "file_path": "/opt/nim/llm/.venv/lib/python3.10/site-packages/uvicorn/protocols/http/httptools_impl.py", "line_number": "481", "message": "10.244.0.1:49976 - \"GET /v1/health/live HTTP/1.1\" 200", "exc_info": "None", "stack_info": "None"}
# {"level": "INFO", "time": "2025-05-27 09:57:47.418", "file_name": "httptools_impl.py", "file_path": "/opt/nim/llm/.venv/lib/python3.10/site-packages/uvicorn/protocols/http/httptools_impl.py", "line_number": "481", "message": "10.244.0.1:49988 - \"GET /v1/health/ready HTTP/1.1\" 200", "exc_info": "None", "stack_info": "None"}
# ```

# %% [markdown]
# しばらく待つとPodがREADY (1/1) になります。

# %%
# !kubectl get pods -n nim-llm
# Out:
# NAME                READY   STATUS    RESTARTS   AGE
# nim-llm-release-0   1/1     Running   0          2m18s

# %% [markdown]
# **想定する出力**
#
# NAME                READY   STATUS    RESTARTS   AGE
# nim-llm-release-0   1/1     Running   0          2m18s

# %% [markdown]
# ### ポートフォワーディング

# %% [markdown]
# システムは複数のプロセスを実行することができるので、実行中のアプリケーションでポートを占有しないようにしなければなりません。以下のコードでは、一意の空きポートを見つけて RAGアプリケーションに割り当てています：

# %%
import random
import socket

def find_available_port(start=11000, end=11999):
    while True:
        # Randomly select a port between start and end range
        port = random.randint(start, end)
        
        # Try to create a socket and bind to the port
        with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as sock:
            try:
                sock.bind(("localhost", port))
                # If binding is successful, the port is free
                return port
            except OSError:
                # If binding fails, the port is in use, continue to the next iteration
                continue

# Find and print an available port
os.environ['CONTAINER_PORT'] = str(find_available_port())
print(f"Your have been alloted the available port: {os.environ['CONTAINER_PORT']}")
# Out:
# Your have been alloted the available port: 11124

# %% [markdown]
# kubectlのport-forwardコマンドをバックグラウンドで実行するためにsubprocessを使っています。（ターミナル上から実行しても構いません）

# %%
import subprocess
subprocess.Popen(f"kubectl port-forward svc/nim-llm-release {os.environ['CONTAINER_PORT']}:8000 \
                 -n nim-llm".split(), stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
# Out:
# <Popen: returncode: None args: ['kubectl', 'port-forward', 'svc/nim-llm-rele...>

# %% [markdown]
# 割り当てたポートを利用してデプロイしたNIM エンドポイント (Pod)にリクエストを投げてみましょう

# %%
# !curl -s -X POST "http://localhost:${CONTAINER_PORT}/v1/chat/completions" \
    -H "accept: application/json" \
    -H "Content-Type: application/json" \
    -d '{ \
        "model": "tokyotech-llm/llama-3.1-swallow-8b-instruct-v0.1", \
        "messages": [ \
            { \
                "role": "user", \
                "content": "日本の首都はどこですか？" \
            } \
        ], \
        "temperature": 0.7, \
        "max_tokens": 50 \
    }' \
    | jq
# Out:
# {
#   "id": "chat-5e8dd5f3d9084596b04af337be67ab1e",
#   "object": "chat.completion",
#   "created": 1748341341,
#   "model": "tokyotech-llm/llama-3.1-swallow-8b-instruct-v0.1",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "東京です。"
#       },
#       "logprobs": null,
#       "finish_reason": "stop",
#       "stop_reason": null
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 18,
#     "total_tokens": 21,
#     "completion_tokens": 3
#   },
#   "prompt_logprobs": null
# }

# %% [markdown]
# **想定される出力**
#
# ```json
# {
#   "id": "chat-5e8dd5f3d9084596b04af337be67ab1e",
#   "object": "chat.completion",
#   "created": 1748341341,
#   "model": "tokyotech-llm/llama-3.1-swallow-8b-instruct-v0.1",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "東京です。"
#       },
#       "logprobs": null,
#       "finish_reason": "stop",
#       "stop_reason": null
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 18,
#     "total_tokens": 21,
#     "completion_tokens": 3
#   },
#   "prompt_logprobs": null
# }
# ```

# %% [markdown]
# ### クイックテストの開始
# NIMが稼働していることを2つの方法で素早くテストできます:
# - LangChain NVIDIA Endpoints
# - 単純なOpenAI完了リクエスト
#
# **パラメータの説明:**
# - **base_url**:  NVIDIA NIM の docker イメージがデプロイされているURL
# - **model**: デプロイされた NVIDIA NIM モデルの名前
# - **temperature**: サンプリングのランダム性を調整する。温度を下げると、高い確率で単語が選択される可能性が高くなります。
# - **top_p**: モデルがどの程度決定論的かを制御します。正確で事実に基づいた回答を求める場合は、この値を低く保ちます。より多様な回答を求める場合は、値を大きくします
# - **max_tokens**: 生成される出力トークンの最大数

# %%
from langchain_nvidia_ai_endpoints import ChatNVIDIA

llm = ChatNVIDIA(base_url="http://0.0.0.0:{}/v1".format(os.environ['CONTAINER_PORT']), model="tokyotech-llm/llama-3.1-swallow-8b-instruct-v0.1", temperature=0.1, max_tokens=1000, top_p=1.0)

result = llm.invoke("フランスの首都はどこですか？")
print(result.content)
# Out:
# パリです。

# %% [markdown]
# エラーが出力された場合は、しばらく待ってから上記のセルを再実行してください。エラーは、NIMコンテナが完全に立ち上がっていないことが原因かもしれません。

# %% [markdown]
# ### RAG アプリケーション
#
# このセクションでは、前のノートブックの手順に従って、ローカルに配置されたNVIDIA NIMをベースとしたRAGアプリケーションを構築します。このデモでは、前のノートブックのように2つのLLMを使って会話型検索チェーンを作るのではなく、1つのLLM `llama-3.1-swallow--8b-instruct` を使って会話型検索チェーンを作ります。これは各NIMイメージには1つのベースモデルがあるからです。ローカルに配置されたNIMとリモートアクセスを使用することも可能ですが、わかりやすくするために、単一のLLMのアプローチにこだわります。

# %% [markdown]
# #### ライブラリのインポート

# %%
from langchain.chains import ConversationalRetrievalChain, LLMChain
from langchain.chains.conversational_retrieval.prompts import CONDENSE_QUESTION_PROMPT, QA_PROMPT
from langchain.chains.question_answering import load_qa_chain
from langchain.memory import ConversationBufferMemory
from langchain.vectorstores import FAISS
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_nvidia_ai_endpoints import ChatNVIDIA
from langchain_nvidia_ai_endpoints import NVIDIAEmbeddings

# %% [markdown]
# #### ウェブリンク・データソースの作成
#
# お好みのウェブリンクを差し替えたり、追加したりすることができます。

# %%
urls = [
"https://www.fsa.go.jp/news/r5/20230829/230829_main.pdf",
"https://www.tioj.or.jp/activity/pdf/190619_06.pdf",
"https://www.pmda.go.jp/files/000251332.pdf",
"https://www.jili.or.jp/files/research/zenkokujittai/pdf/r3/i-xvii.pdf",
"https://www.zenginkyo.or.jp/fileadmin/res/news/news350331_1.pdf"
]

# %% [markdown]
# ## 実装

# %%
# !uv pip install pypdf
# Out:
# Using Python 3.10.17 environment at: /home/turabe/Documents/uv/base
# Audited 1 package in 6ms

# %% [markdown]
# #### PDF ファイルを読み込む関数を作る
#
# 以下は、PDFファイルを読み込むためのヘルパー関数です。

# %%
from pypdf import PdfReader
from io import BytesIO
import requests
import re

def clean_japanese_pdf_text(text: str) -> str:
    # 日本語文中の改行を削除
    text = re.sub(r'(?<=[ぁ-んァ-ヶ一-龥])\s*\n\s*(?=[ぁ-んァ-ヶ一-龥])', '', text)
    # 連続するスペースや全角スペースを1つにまとめる
    text = re.sub(r'[ 　]{2,}', ' ', text)
    # 各行の先頭空白を削除
    text = re.sub(r'^\s+', '', text, flags=re.MULTILINE)
    # 「..... 4」形式の目次行のページ番号を除去
    text = re.sub(r'\.{3,}\s*\d{1,3}', '', text)
    text = text.replace("\n", "")
    return text

def pdf_document_loader(url: str) -> str:
    """
    Loads and extracts cleaned text from a PDF at the given URL using `pypdf`.

    Args:
        url: The URL of the PDF.

    Returns:
        Cleaned text content of the PDF.
    """
    try:
        response = requests.get(url)
        response.raise_for_status()
        reader = PdfReader(BytesIO(response.content))
        text = ""
        for page in reader.pages:
            extracted = page.extract_text()
            if extracted:
                text += extracted
        return clean_japanese_pdf_text(text.strip())
    except Exception as e:
        print(f"Failed to load {url} due to: {e}")
        return ""

# %% [markdown]
# #### 埋め込みとDocument Text Splitterの作成
#
# 埋め込みを保存するパスを初期化し、`pdf_document_loader`関数を実行し、ドキュメントをテキストの塊に分割する関数を作ってみましょう。

# %%
from tqdm import tqdm

def create_embeddings(embeddings_model,embedding_path: str = "./embed"):

    embedding_path = "./embed"
    print(f"Storing embeddings to {embedding_path}")

    documents = []
    for url in tqdm(urls):
        print(url)
        document = pdf_document_loader(url)
        #document = html_document_loader(url)
        documents.append(document)


    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=500,
        chunk_overlap=0,
        length_function=len,
    )
    print("Total documents:",len(documents))
    texts = text_splitter.create_documents(documents)
    print("Total texts:",len(texts))
    index_docs(embeddings_model,url, text_splitter, texts, embedding_path,)
    print("Generated embedding successfully")

# %% [markdown]
# #### LangChainからNVIDIA AI Endpointsを使って埋め込みを生成する
#
# このセクションでは、LangChain用のNVIDIA AI Endpointsを使って埋め込みを生成し、将来の再利用のためにエンベッディングを`/embed`ディレクトリのオフラインベクタストアに保存する方法をデモします。

# %%
embeddings_model = NVIDIAEmbeddings(model="NV-Embed-QA") # or use nvidia/nv-embedqa-e5-v5

# %% [markdown]
# 以下では、ドキュメントページのコンテンツをループしてテキストとメタデータを拡張し、[FAISS](https://faiss.ai/index.html)を適用する `index_docs` 関数を作成します。埋め込みはローカルに保存されます。

# %%
from typing import List, Union


def index_docs(embeddings_model, url: Union[str, bytes], splitter, documents: List[str], dest_embed_dir: str) -> None:
    """
    Split the documents into chunks and create embeddings for them.
    
    Args:
        embeddings_model: Model used for creating embeddings.
        url: Source url for the documents.
        splitter: Splitter used to split the documents.
        documents: List of documents whose embeddings need to be created.
        dest_embed_dir: Destination directory for embeddings.
    """
    texts = []
    metadatas = []

    for document in documents:
        chunk_texts = splitter.split_text(document.page_content)
        texts.extend(chunk_texts)
        metadatas.extend([document.metadata] * len(chunk_texts))

    if os.path.exists(dest_embed_dir):
        docsearch = FAISS.load_local(
            folder_path=dest_embed_dir, 
            embeddings=embeddings_model, 
            allow_dangerous_deserialization=True
        )
        docsearch.add_texts(texts, metadatas=metadatas)
    else:
        docsearch = FAISS.from_texts(texts, embedding=embeddings_model, metadatas=metadatas)

    docsearch.save_local(folder_path=dest_embed_dir)

# %% [markdown]
# #### ベクターストアからの埋め込みのロードとNVIDIA Endpointを使用したRAGの構築
#
# 次に、関数 `create_embeddings` を呼び出し、FAISSを使って[vector store](https://developer.nvidia.com/blog/accelerating-vector-search-fine-tuning-gpu-index-algorithms/)から文書を読み込む。ベクトルストアはembeddingsと呼ばれる高次元空間に関連情報を格納しています。
#
# 以下の2つのセルを実行してください。

# %%
# %%time
create_embeddings(embeddings_model=embeddings_model)
# Out:
# Storing embeddings to ./embed
#   0%|          | 0/5 [00:00<?, ?it/s]
# https://www.fsa.go.jp/news/r5/20230829/230829_main.pdf
#  20%|██        | 1/5 [00:00<00:01,  2.68it/s]
# https://www.tioj.or.jp/activity/pdf/190619_06.pdf
#  40%|████      | 2/5 [00:02<00:03,  1.24s/it]
# https://www.pmda.go.jp/files/000251332.pdf
#  60%|██████    | 3/5 [00:03<00:02,  1.15s/it]
# https://www.jili.or.jp/files/research/zenkokujittai/pdf/r3/i-xvii.pdf
#  80%|████████  | 4/5 [00:03<00:00,  1.21it/s]
# https://www.zenginkyo.or.jp/fileadmin/res/news/news350331_1.pdf
# 100%|██████████| 5/5 [00:03<00:00,  1.28it/s]
# Total documents: 5
# Total texts: 260
# Generated embedding successfully
# CPU times: user 2.61 s, sys: 59.7 ms, total: 2.67 s
# Wall time: 8.25 s

# %%
# load Embed documents
embedding_path = "./embed/"
docsearch = FAISS.load_local(folder_path=embedding_path, embeddings=embeddings_model, allow_dangerous_deserialization=True)

# %% [markdown]
# ### llama-3.1-swallow-8b-instructで会話型検索チェーンを作る
#
# デプロイされたNIMは`http://0.0.0.0:8000`で稼働しているので、NIMの基本モデル`llama-3.1-swallow-8b-instruct`に基づいて[会話型検索チェーン](https://python.langchain.com/v0.1/docs/modules/chains/#conversationalretrievalchain-with-streaming-to-stdout)を作成する。

# %%
llm = ChatNVIDIA(base_url="http://0.0.0.0:{}/v1".format(os.environ['CONTAINER_PORT']),
                 model="tokyotech-llm/llama-3.1-swallow-8b-instruct-v0.1", temperature=0.0, max_tokens=1000, top_p=1.0)

memory = ConversationBufferMemory(memory_key="chat_history", return_messages=True)

qa_prompt=QA_PROMPT

doc_chain = load_qa_chain(llm, chain_type="stuff", prompt=QA_PROMPT)

qa = ConversationalRetrievalChain.from_llm(
    llm=llm,
    retriever=docsearch.as_retriever(),
    chain_type="stuff",
    memory=memory,
    combine_docs_chain_kwargs={'prompt': qa_prompt},
)
# Out:
# /tmp/ipykernel_1013693/1621665863.py:4: LangChainDeprecationWarning: Please see the migration guide at: https://python.langchain.com/docs/versions/migrating_memory/
#   memory = ConversationBufferMemory(memory_key="chat_history", return_messages=True)
# /tmp/ipykernel_1013693/1621665863.py:8: LangChainDeprecationWarning: This class is deprecated. See the following migration guides for replacements based on `chain_type`:
# stuff: https://python.langchain.com/docs/versions/migrating_chains/stuff_docs_chain
# map_reduce: https://python.langchain.com/docs/versions/migrating_chains/map_reduce_chain
# refine: https://python.langchain.com/docs/versions/migrating_chains/refine_chain
# map_rerank: https://python.langchain.com/docs/versions/migrating_chains/map_rerank_docs_chain
#
# See also guides on retrieval and question-answering here: https://python.langchain.com/docs/how_to/#qa-with-rag
#   doc_chain = load_qa_chain(llm, chain_type="stuff", prompt=QA_PROMPT)

# %% [markdown]
# ### クエリによるテスト

# %%
query = "世帯主が不意の事故により入院が必要になる場合の必要資金について、60～64歳及び65歳以上の夫婦が公的年金以 \
        外に必要とする月間生活資金と比較してください。"
result = qa({"question": query})
print(result.get("answer"))
# Out:
# /tmp/ipykernel_1013693/2744485627.py:3: LangChainDeprecationWarning: The method `Chain.__call__` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   result = qa({"question": query})
# 世帯主が不意の事故により入院が必要になる場合の必要資金について、60～64歳及び65歳以上の夫婦が公的年金以外に必要とする月間生活資金は、60～64歳の間が20.2万円、65歳以降では16.1万円となっている。

# %%
query = "製造たばこの個包装及び中間包装に求められる識別マークの表示方法の条件について説明してください。"
result = qa({"question": query})
print(result.get("answer"))
# Out:
# 申し訳ございませんが、提供されたテキストには、製造たばこの個包装及び中間包装に求められる識別マークの表示方法の条件についての情報は含まれていません。テキストは、がん原性試験における毒性学的指標と投与計画についての情報を提供しています。

# %% [markdown]
# 先に進む前に、helmをアンインストールしてGPUのVRAMを解放しましょう。

# %%
! helm uninstall nim-llm-release -n nim-llm
# Out:
# release "nim-llm-release" uninstalled

# %% [markdown]
# 次のノートブックでは、LoRAのようなPEFTの機能をNIMに追加する方法を説明します。

# %% [markdown]
# ---
#
# ## References
#
# - https://developer.nvidia.com/blog/tips-for-building-a-rag-pipeline-with-nvidia-ai-langchain-ai-endpoints/
# - https://nvidia.github.io/GenerativeAIExamples/latest/notebooks/05_RAG_for_HTML_docs_with_Langchain_NVIDIA_AI_Endpoints.html
#
# ## Licensing
#
# Copyright © 2024 OpenACC-Standard.org. This material is released by OpenACC-Standard.org, in collaboration with NVIDIA Corporation, under the Creative Commons Attribution 4.0 International (CC BY 4.0). These materials include references to hardware and software developed by other entities; all applicable licensing and copyrights apply.

# %% [markdown]
# <br>
# <div>
#     <span style="float: left; width: 33%; text-align: left;"><a href="rag_nim_endpoints.ipynb">Previous Notebook</a></span>
#     <span style="float: left; width: 34%; text-align: center;">
#         <a href="rag_nim_endpoints.ipynb">1</a>
#         <a >2</a>
#         <a href="nim_lora_adapter.ipynb">3</a>
#         <!-- <a href="challenge.ipynb">4</a> -->
#     </span>
#     <span style="float: left; width: 33%; text-align: right;"><a href="nim_lora_adapter.ipynb">Next Notebook</a></span>
# </div>
#
# <br>
# <p> <center> <a href="../../Start-NIM-RAG.ipynb">Home Page</a> </center> </p>
